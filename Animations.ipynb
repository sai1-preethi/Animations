# %%
import cv2
import numpy as np

# %%
img=cv2.imread(r"C:\Users\Lenovo\Downloads\dog,cat\dog\DOg420.jpg")

# %%
img.shape

# %%
cv2.namedWindow("pi",flags=cv2.WINDOW_AUTOSIZE) # we are creating new window with a new window

# %%
cv2.imshow("pi",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
def mouse_tracking(event,x,y,flags,param):
    print("preethi")

# %%
cv2.namedWindow("mouse tracking")

cv2.setMouseCallback("mouse tracking",mouse_tracking)

black_image=np.zeros((500,500),dtype=np.uint8)

while True:
    cv2.imshow("mouse tracking",black_image)

    if cv2.waitKey(1) & 255==ord("q"):
        break

cv2.destroyAllWindows()
# Out:
# 465 433
# 432 420
# 394 407
# 358 395
# 326 382
# 296 370
# 272 357
# 230 335
# 214 327
# 202 319
# 192 315
# 183 308
# 178 304
# 175 300
# 173 299
# 171 298
# 170 297
# 170 296
# 170 295
# 174 295
# 182 294
# 198 293
# 198 293
# 205 293
# 213 293
# 232 292
# 241 292
# 250 292
# 264 293
# 271 293
# 275 295
# 282 295
# 287 295
# 290 295
# 293 295
# 296 295
# 298 295
# 299 296
# 301 297
# 302 297
# 303 298
# 305 299
# 306 299
# 307 301
# 309 302
# 310 303
# 310 304
# 310 306
# 311 307
# 311 307
# 311 308
# 311 309
# 311 310
# 311 311
# 310 312
# 308 315
# 306 317
# 303 319
# 298 323
# 296 324
# 294 325
# 290 327
# 287 328
# 285 331
# 282 331
# 281 333
# 278 334
# 276 335
# 275 336
# 274 337
# 272 338
# 270 338
# 267 339
# 264 340
# 262 340
# 261 340
# 259 340
# 258 340
# 256 340
# 254 340
# 250 339
# 248 339
# 246 339
# 241 336
# 240 335
# 238 335
# 235 334
# 230 331
# 228 329
# 224 327
# 220 324
# 216 321
# 214 319
# 213 318
# 210 316
# 208 313
# 206 311
# 202 307
# 201 304
# 199 302
# 195 294
# 194 292
# 192 291
# 190 287
# 188 285
# 186 282
# 183 279
# 182 276
# 175 269
# 175 269
# 174 266
# 171 263
# 169 259
# 167 256
# 166 255
# 165 253
# 163 251
# 163 249
# 162 247
# 162 246
# 161 243
# 161 240
# 161 239
# 161 238
# 161 235
# 162 231
# 162 229
# 165 227
# 168 222
# 170 219
# 175 216
# 178 215
# 181 211
# 184 209
# 189 207
# 191 207
# 193 205
# 199 202
# 205 201
# 210 199
# 218 198
# 223 198
# 233 197
# 238 196
# 246 196
# 250 196
# 253 196
# 259 196
# 262 196
# 266 196
# 268 196
# 270 196
# 271 196
# 272 196
# 273 196
# 274 196
# 274 197
# 274 198
# 274 199
# 274 200
# 274 204
# 274 206
# 274 209
# 274 212
# 274 216
# 274 219
# 274 224
# 274 232
# 274 235
# 274 239
# 274 246
# 274 248
# 274 251
# 274 253
# 274 256
# 274 256
# 274 257
# 275 257
# 275 258
# 281 253
# 290 244
# 300 235
# 310 223
# 322 211
# 335 196
# 348 183
# 362 168
# 373 156
# 382 146
# 390 136
# 397 128
# 407 117
# 411 111
# 414 108
# 416 104
# 418 103
# 418 101
# 421 96
# 422 95
# 423 92
# 424 90
# 425 87
# 425 85
# 426 82
# 426 81
# 426 79
# 427 77
# 427 75
# 428 73
# 429 71
# 429 68
# 430 67
# 430 63
# 431 59
# 432 58
# 434 52
# 434 49
# 436 44
# 442 35
# 445 31
# 449 24
# 450 21
# 452 16
# 454 13
# 456 11
# 457 9
# 458 7
# 458 6
# 458 6
# 458 5
# 458 4
# 459 3
# 461 2
# 462 1

# %%
def mouse_tracking(event,x,y,flags,param):
    if event!=0 and event!=1 and event!=4:
        print(event)

# %%
def mouse_tracking(event,x,y,flags,param):
    print(x,y)

# %%
def mouse_tracking(event,x,y,flags,param):
    if event==1:
        cv2.circle(black_image,(x,y),9,(0,0,255),-1)
    elif event==2:
        cv2.circle(black_image,(x,y),9,(0,255,0),-1)

# %%
cv2.namedWindow("mouse tracking")

cv2.setMouseCallback("mouse tracking",mouse_tracking)

black_image=np.zeros((500,500),dtype=np.uint8)


while True:
    cv2.imshow("mouse tracking",black_image)

    if cv2.waitKey(1) & 255==ord("q"):
        break

cv2.destroyAllWindows()

# %%
cv2.namedWindow("mouse tracking")

cv2.setMouseCallback("mouse tracking",mouse_tracking)

black_image=np.zeros((500,500),dtype=np.uint8)

while True:
    cv2.imshow("mouse tracking",black_image)

    if cv2.waitKey(1) & 255==ord("s"):
        cv2.imwrite(r"C:\Users\Lenovo\Downloads\dog,cat\dog\DOg420.jpg{}.format(image))
        cv2.waitKey(1) & 255==ord("q"):
        break

cv2.destroyAllWindows()

# %%
import os

# %%
os.mkdir(r"C:\Users\LENOVO\Downloads\frames"):
# Out:
#   Cell In[3], line 1
#     os.mkdir(r"C:\Users\LENOVO\Downloads\frames"):
#                                                  ^
# SyntaxError: invalid syntax

# %%
for images in os.listdir(r"C:\Users\LENOVO\Downloads\frames"):
    img=cv2.imread(r"C:\Users\LENOVO\Downloads\frames\{}".format(images))

    cv2.imshow("pi1",image)
    cv2.waitKey(1) 
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for images in os.listdir(r"C:\Users\LENOVO\Downloads\frames"):
#       2     img=cv2.imread(r"C:\Users\LENOVO\Downloads\frames\{}".format(images))
#       4     cv2.imshow("pi1",image)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\LENOVO\\Downloads\\frames'

# %%
# to create a line in pop up

# %%
x1=-1
y1=-1
def mouse_tracking(event,x,y,flags,parm):
    global x1,y1
    if event==1:q
        x1=x
        y1=y

    if event==2:
        cv2.line(black_image,(x1,y1),(x,y),(0,0,255),2)  
    elif event == 7: 
        cv2.circle()

# %%
import cv2

# %%
import os

# %%
os.mkdir(r"C:\Users\Lenovo\Downloads\project")

# %%
cv2.namedWindow("mouse tracking")

cv2.setMouseCallback("mouse tracking",mouse_tracking)
c=3
#black_image=np.full((500,500,3),(100,245,200),dtype=np.uint8) 
black_image = cv2.imread(r"C:\Users\Lenovo\Downloads\project\.jpg")

c=0

while True:
    cv2.imshow("mouse tracking",black_image) 
    if cv2.waitKey(1) & 255==ord("s"):
        cv2.imwrite(r"C:\Users\Lenovo\Downloads\project\{}.jpg".format(c),black_image) 
        print("image:{}".format(c))
        c+=1


    if cv2.waitKey(1) & 255==ord("q"):
        break

cv2.destroyAllWindows()

# %% [markdown]
# # Cropping the video

# %%
x1=-1
y1=-2
def mouse_tracking(event,x,y,flags,param):
    global x1,y1
    if event==1:
        x1=x
        y1=y

    if event==4:
        cv2.rectangle(img,(x1,y1),(x,y),(0,0,255),2)

    cv2.imshow("cropped_img",img[y1:y,x1:x])
    if cv2.waitKey(1) & 255 == ord("r"):
        pass
    
cv2.destroyAllWindows()

# %%
cv2.namedWindow("mouse tracking")

cv2.setMouseCallback("mouse tracking",mouse_tracking)

vid=cv2.videoCapture(0)
c=0

while True:
    suc,img=vid.read()
    cv2.imshow("mouse tracking",img)

    if cv2.waitKey(1) & 255==ord("q"):
        break

cv2.destroyAllWindows()
